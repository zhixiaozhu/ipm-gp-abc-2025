# %%
# This jupternote is used to compute and compare Long-term forecasting performance of the three methods 
#  only for testing years (2009-2012), given true population structure at 2008.
# As this is an expriments added retrospectively, the code is not well organized add didn't add to the main files. 
# The code that is commented out were used to generate the simulation.

# %%
# # for ABC
# from r1_data_generating import *

# samples_grw_f = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_grw_f_whole.pkl", mode="rb"))
# samples_grw_nf = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_grw_nf_whole.pkl", mode="rb"))
# samples_sur = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_sur_whole.pkl", mode="rb"))
# samples_fec = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_fec_whole.pkl", mode="rb"))
# samples_flow = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_flow_whole.pkl", mode="rb")) 
# Time_test = 4
# for i in range(Time_test):
#     globals()[f'p_test{i}'] = pickle.load(open(file = os.getcwd()+f"/true_popu/popu_dataset{5+i}.pkl", mode="rb"))
# popu_test = {i: globals()[f'p_test{i}'] for i in range(Time_test)}
# for i in range(Time_test):
#     del(globals()[f'p_test{i}']) 

# whole_year = ipmmcmc_whole(popu_dataset_whole=popu_whole, popu_0toT=popu_test[0], 
#                             z0=popu_structure_noid_current(popu_test[0]), 
#                             tmax_list=w.iloc[0][5:10], tmin_list=w.iloc[1][5:9], precip_list=w.iloc[2][5:9],
#                             alpha=theta_mle_whole.loc[0, 'alpha'], beta=theta_mle_whole.loc[0, 'beta'], recruit_p=theta_mle_whole.loc[0, 'recruit_p'])

# # Loading MCMC samples
# # HMC for the other vital rates.
# # Grw_nf
# whole_year.m_grw_nf_new = gpflow.models.GPR(data=(XY_grw_nf_compu(popu_whole, env=True)), 
#                                                 kernel=gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])), 
#                                                 mean_function=None)

# # we add priors to the hyperparameters.
# whole_year.m_grw_nf_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_grw_nf_new.likelihood.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_grw_nf_new.kernel.lengthscales.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.hmc_helper_grw_nf = gpflow.optimizers.SamplingHelper(
#     whole_year.m_grw_nf_new.log_posterior_density, whole_year.m_grw_nf_new.trainable_parameters
# )

# whole_year.samples_grw_nf = samples_grw_nf

# # Fec
# whole_year.m_fec_new = gpflow.models.GPMC(data=(XY_fec_compu(popu_whole, env=True)), 
#                             kernel=gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])) , 
#                             likelihood=gpflow.likelihoods.Bernoulli())

# whole_year.m_fec_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_fec_new.kernel.lengthscales.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))

# whole_year.hmc_helper_fec = gpflow.optimizers.SamplingHelper(
#     whole_year.m_fec_new.log_posterior_density, whole_year.m_fec_new.trainable_parameters
# )

# whole_year.samples_fec = samples_fec

# # Flow poi
# whole_year.m_flow_poi_new = gpflow.models.GPMC(data=(XY_flow_compu(popu_whole, env=True)), 
#                                     kernel=gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])), 
#                                     likelihood=gpflow.likelihoods.Poisson())

# whole_year.m_flow_poi_new.kernel.lengthscales.prior =  tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_flow_poi_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))

# whole_year.hmc_helper_flow = gpflow.optimizers.SamplingHelper(
#     whole_year.m_flow_poi_new.log_posterior_density, whole_year.m_flow_poi_new.trainable_parameters
# )

# whole_year.samples_flow = samples_flow


# # Grw_f
# whole_year.m_grw_f_new = gpflow.models.GPR(data=(XY_grw_f_compu(popu_whole, env=True)), 
#                                 kernel= gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])), mean_function=None)

# whole_year.m_grw_f_new.kernel.lengthscales.prior =  tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_grw_f_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_grw_f_new.likelihood.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))

# whole_year.hmc_helper_grw_f = gpflow.optimizers.SamplingHelper(
#     whole_year.m_grw_f_new.log_posterior_density, whole_year.m_grw_f_new.trainable_parameters
# )

# whole_year.samples_grw_f = samples_grw_f

# # Sur
# whole_year.m_sur_new = gpflow.models.GPMC(data=(XY_sur_compu(popu_whole, env=True)), 
#                             kernel=gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])) , 
#                             likelihood=gpflow.likelihoods.Bernoulli())

# whole_year.m_sur_new.kernel.lengthscales.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_sur_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))

# whole_year.hmc_helper_sur = gpflow.optimizers.SamplingHelper(
#     whole_year.m_sur_new.log_posterior_density, whole_year.m_sur_new.trainable_parameters
# )

# whole_year.samples_sur = samples_sur




# whole_year.recru_full = pickle.load(open(file = os.getcwd()+f"/true_popu/mle/theta_mle_full.pkl", mode="rb"))[5:9].reset_index(drop=True)
# whole_year.popu_all = popu_test
# # predicting lambdas
# ray.init(log_to_driver=False)
# print('\n Simulation starts! \n')

# whole_year.true_z_allsteps = False 
# whole_year.abc_index = np.load(open(file = os.getcwd()+f"/ABC_details/p_index_10.pkl", mode="rb"))
# whole_year.weight = np.load(open(file = os.getcwd()+f"/ABC_details/weight10.pkl", mode="rb"))

# b = np.array(whole_year.prediction_para(total_samples=5000, abc=True),  dtype=object)
# np.save(open(file = os.getcwd()+"/true_popu/simulations/simu_abc_testingyears.pkl", mode="wb"), b)
# Out:
#  Loading processed population datasets...
#
#
#
#
#  Loading MLEs for the processed population datasets...
# 2026-04-16 17:35:52,976	INFO worker.py:1673 -- Started a local Ray instance.
#  Simulation starts!

# %%
# # for GP
# from r1_data_generating import *

# samples_grw_f = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_grw_f_whole.pkl", mode="rb"))
# samples_grw_nf = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_grw_nf_whole.pkl", mode="rb"))
# samples_sur = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_sur_whole.pkl", mode="rb"))
# samples_fec = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_fec_whole.pkl", mode="rb"))
# samples_flow = pickle.load(open(file = os.getcwd()+f"/true_popu/mcmc/samples_flow_whole.pkl", mode="rb")) 
# Time_test = 4
# for i in range(Time_test):
#     globals()[f'p_test{i}'] = pickle.load(open(file = os.getcwd()+f"/true_popu/popu_dataset{5+i}.pkl", mode="rb"))
# popu_test = {i: globals()[f'p_test{i}'] for i in range(Time_test)}
# for i in range(Time_test):
#     del(globals()[f'p_test{i}']) 

# whole_year = ipmmcmc_whole(popu_dataset_whole=popu_whole, popu_0toT=popu_test[0], 
#                             z0=popu_structure_noid_current(popu_test[0]), 
#                             tmax_list=w.iloc[0][5:10], tmin_list=w.iloc[1][5:9], precip_list=w.iloc[2][5:9],
#                             alpha=theta_mle_whole.loc[0, 'alpha'], beta=theta_mle_whole.loc[0, 'beta'], recruit_p=theta_mle_whole.loc[0, 'recruit_p'])

# # Loading MCMC samples
# # HMC for the other vital rates.
# # Grw_nf
# whole_year.m_grw_nf_new = gpflow.models.GPR(data=(XY_grw_nf_compu(popu_whole, env=True)), 
#                                                 kernel=gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])), 
#                                                 mean_function=None)

# # we add priors to the hyperparameters.
# whole_year.m_grw_nf_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_grw_nf_new.likelihood.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_grw_nf_new.kernel.lengthscales.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.hmc_helper_grw_nf = gpflow.optimizers.SamplingHelper(
#     whole_year.m_grw_nf_new.log_posterior_density, whole_year.m_grw_nf_new.trainable_parameters
# )

# whole_year.samples_grw_nf = samples_grw_nf

# # Fec
# whole_year.m_fec_new = gpflow.models.GPMC(data=(XY_fec_compu(popu_whole, env=True)), 
#                             kernel=gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])) , 
#                             likelihood=gpflow.likelihoods.Bernoulli())

# whole_year.m_fec_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_fec_new.kernel.lengthscales.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))

# whole_year.hmc_helper_fec = gpflow.optimizers.SamplingHelper(
#     whole_year.m_fec_new.log_posterior_density, whole_year.m_fec_new.trainable_parameters
# )

# whole_year.samples_fec = samples_fec

# # Flow poi
# whole_year.m_flow_poi_new = gpflow.models.GPMC(data=(XY_flow_compu(popu_whole, env=True)), 
#                                     kernel=gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])), 
#                                     likelihood=gpflow.likelihoods.Poisson())

# whole_year.m_flow_poi_new.kernel.lengthscales.prior =  tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_flow_poi_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))

# whole_year.hmc_helper_flow = gpflow.optimizers.SamplingHelper(
#     whole_year.m_flow_poi_new.log_posterior_density, whole_year.m_flow_poi_new.trainable_parameters
# )

# whole_year.samples_flow = samples_flow


# # Grw_f
# whole_year.m_grw_f_new = gpflow.models.GPR(data=(XY_grw_f_compu(popu_whole, env=True)), 
#                                 kernel= gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])), mean_function=None)

# whole_year.m_grw_f_new.kernel.lengthscales.prior =  tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_grw_f_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_grw_f_new.likelihood.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))

# whole_year.hmc_helper_grw_f = gpflow.optimizers.SamplingHelper(
#     whole_year.m_grw_f_new.log_posterior_density, whole_year.m_grw_f_new.trainable_parameters
# )

# whole_year.samples_grw_f = samples_grw_f

# # Sur
# whole_year.m_sur_new = gpflow.models.GPMC(data=(XY_sur_compu(popu_whole, env=True)), 
#                             kernel=gpflow.kernels.RBF(lengthscales=np.array([1,1,1,1,1])) , 
#                             likelihood=gpflow.likelihoods.Bernoulli())

# whole_year.m_sur_new.kernel.lengthscales.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))
# whole_year.m_sur_new.kernel.variance.prior = tfd.Normal(loc=f64(0.), scale=f64(100.))

# whole_year.hmc_helper_sur = gpflow.optimizers.SamplingHelper(
#     whole_year.m_sur_new.log_posterior_density, whole_year.m_sur_new.trainable_parameters
# )

# whole_year.samples_sur = samples_sur




# whole_year.recru_full = pickle.load(open(file = os.getcwd()+f"/true_popu/mle/theta_mle_full.pkl", mode="rb"))[5:9].reset_index(drop=True)
# whole_year.popu_all = popu_test
# # predicting lambdas
# ray.init(log_to_driver=False)
# print('\n Simulation starts! \n')

# whole_year.true_z_allsteps = False 
# whole_year.abc_index = np.load(open(file = os.getcwd()+f"/ABC_details/p_index_ini.pkl", mode="rb"))

# b = np.array(whole_year.prediction_para(total_samples=5000, abc=False),  dtype=object)
# np.save(open(file = os.getcwd()+"/true_popu/simulations/simu_random_testingyears.pkl", mode="wb"), b)
# Out:
#  Loading processed population datasets...
#
#
#
#
#  Loading MLEs for the processed population datasets...
# 2026-04-16 18:11:49,762	INFO worker.py:1673 -- Started a local Ray instance.
#  Simulation starts!

# %%
from r1_data_generating import *
# Out:
#  Loading processed population datasets...
#
#
#
#
#  Loading MLEs for the processed population datasets...

# %%
# Loading true observations
nt_true = []; popu_0toT_all = {}
for i in range(0, 9):
    popu_0toT_all[i] = pickle.load(open(file = os.getcwd()+f"/true_popu/popu_dataset{i}.pkl", mode="rb"))
    n_new1 = np.sum(popu_0toT_all[i]["surv"] == 1)
    n_new2 = np.sum(np.isnan(popu_0toT_all[i]["size"])) 
    nt_true.append((n_new1+n_new2))
    
# for MCMCs (GP)
a = np.load(open(file = os.getcwd()+"/true_popu/simulations/simu_random.pkl", mode="rb"), allow_pickle=True)
nt_random = np.array([item for sublist in a[:, 3] for item in sublist])[:, 5:9]
a_z = np.load(open(file = os.getcwd()+"/true_popu/simulations/simu_random_z.pkl", mode="rb"), allow_pickle=True)
nt_random_z = np.array([item for sublist in a_z[:, 3] for item in sublist])[:, 5:9]
a_tesingyears = np.load(open(file = os.getcwd()+"/true_popu/simulations/simu_random_testingyears.pkl", mode="rb"), allow_pickle=True)
nt_random_test = np.array([item for sublist in a_tesingyears[:, 3] for item in sublist])

# for ABC
b_z = np.load(open(file = os.getcwd()+"/true_popu/simulations/simu_abc_z.pkl", mode="rb"), allow_pickle=True)
nt_abc_z = np.array([item for sublist in b_z[:, 3] for item in sublist])[:, 5:9]
# nt_abc_z = np.concatenate([np.zeros((5029, 1), dtype='int')+nt_true[4], nt_abc_z], axis=1)
b = np.load(open(file = os.getcwd()+"/true_popu/simulations/simu_abc.pkl", mode="rb"), allow_pickle=True)
nt_abc = np.array([item for sublist in b[:, 3] for item in sublist])[:, 5:9]
b_tesingyears = np.load(open(file = os.getcwd()+"/true_popu/simulations/simu_abc_testingyears.pkl", mode="rb"), allow_pickle=True)
nt_abc_test = np.array([item for sublist in b_tesingyears[:, 3] for item in sublist])

# for GLM
# nt_abc = np.concatenate([np.zeros((5029, 1), dtype='int')+nt_true[4], nt_abc], axis=1)
# nt_abc_test = np.concatenate([np.zeros((5000, 1), dtype='int')+nt_true[4], nt_abc_test], axis=1)
# For GLMs
c = np.load(open(file = os.getcwd()+"/true_popu/simulations/glm_simulations", mode="rb"))
nt_glm = np.array(c[:, 2])[:, 5:9]

c_z = np.load(open(file = os.getcwd()+"/true_popu/simulations/glm_simulations_z", mode="rb"))
nt_glm_z = np.array(c_z[:, 2])[:, 5:9]

c_tesingyears = np.load(open(file = os.getcwd()+"/true_popu/simulations/glm_simulations_testingyears.pkl", mode="rb"))
nt_glm_test = c_tesingyears

# %%
fig = plt.figure(figsize=(18, 12))
ax = fig.add_subplot(2, 2, 1)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.spines['left'].set_position(('outward', 3)); ax.spines['left'].set_alpha(0.2); ax.spines['bottom'].set_alpha(0.2)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
plt.plot(np.log(np.median(nt_glm_z, axis=0)), color="green", label='GLM_1step')
plt.plot(np.log(np.median(nt_glm, axis=0)), color="C4", label='GLM_longterm')
plt.plot(np.log(np.median(nt_glm_test, axis=0)), color="C7", label='GLM_testyear')

plt.plot(np.log(nt_true[5:9]), color="r")

plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_glm_test, 0.025, axis=0)), 
    np.log(np.quantile(nt_glm_test, 0.975, axis=0)),
    color="C7",
    alpha=0.2,
)
plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_glm, 0.025, axis=0)), 
    np.log(np.quantile(nt_glm, 0.975, axis=0)),
    color="C4",
    alpha=0.2,
)
plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_glm_z, 0.025, axis=0)), 
    np.log(np.quantile(nt_glm_z, 0.975, axis=0)),
    color="green",
    alpha=0.2,
)
plt.xticks(ticks = np.arange(0, 4), labels= np.arange(2009, 2013), fontsize=14)
plt.legend(loc='lower left', fontsize=14)
# plt.xlabel('Year', fontsize=12)
plt.ylabel('Log Population size', fontsize=12)
plt.ylim(3, 6.5)
plt.title('(A) GLM', fontsize=12)

ax = fig.add_subplot(2, 2, 2)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.spines['left'].set_position(('outward', 3)); ax.spines['left'].set_alpha(0.2); ax.spines['bottom'].set_alpha(0.2)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)

plt.plot(np.log(np.median(nt_random_z, axis=0)), color="green", label='GP_1step')
plt.plot(np.log(np.median(nt_random, axis=0)), color="C4", label='GP_longterm')
plt.plot(np.log(np.median(nt_random_test, axis=0)), color="C0", label='GP_testyear')

plt.plot(np.log(nt_true[5:9]), color="r")

plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_random_test, 0.025, axis=0)), 
    np.log(np.quantile(nt_random_test, 0.975, axis=0)),
    color="C0",
    alpha=0.2,
)
plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_random, 0.025, axis=0)), 
    np.log(np.quantile(nt_random, 0.975, axis=0)),
    color="C4",
    alpha=0.2,
)
plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_random_z, 0.025, axis=0)), 
    np.log(np.quantile(nt_random_z, 0.975, axis=0)),
    color="green",
    alpha=0.2,
)
plt.xticks(ticks = np.arange(0, 4), labels= np.arange(2009, 2013), fontsize=14)
plt.legend(loc='lower left', fontsize=14)
# plt.xlabel('Year', fontsize=12)
plt.ylabel('Log Population size', fontsize=12)
plt.ylim(3, 6.5)
plt.title('(B) GP', fontsize=12)


ax = fig.add_subplot(2, 2, 3)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.spines['left'].set_position(('outward', 3)); ax.spines['left'].set_alpha(0.2); ax.spines['bottom'].set_alpha(0.2)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)

plt.plot(np.log(np.median(nt_abc_z, axis=0)), color="green", label='ABC_1step')
plt.plot(np.log(np.median(nt_abc, axis=0)), color="C4", label='ABC_longterm')
plt.plot(np.log(np.median(nt_abc_test, axis=0)), color="C1", label='ABC_testyear')

plt.plot(np.log(nt_true[5:9]), color="r")

plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_abc_test, 0.025, axis=0)), 
    np.log(np.quantile(nt_abc_test, 0.975, axis=0)),
    color="C1",
    alpha=0.2,
)
plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_abc, 0.025, axis=0)), 
    np.log(np.quantile(nt_abc, 0.975, axis=0)),
    color="C4",
    alpha=0.2,
)
plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_abc_z, 0.025, axis=0)), 
    np.log(np.quantile(nt_abc_z, 0.975, axis=0)),
    color="green",
    alpha=0.2,
)
plt.xticks(ticks = np.arange(0, 4), labels= np.arange(2009, 2013), fontsize=14)
plt.legend(loc='lower left', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Log Population size', fontsize=12)
plt.ylim(3, 6.5)
plt.title('(C) ABC', fontsize=12)

ax = fig.add_subplot(2, 2, 4)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.spines['left'].set_position(('outward', 3)); ax.spines['left'].set_alpha(0.2); ax.spines['bottom'].set_alpha(0.2)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)


plt.plot(np.log(np.median(nt_random_test, axis=0)), color="C0", label='GP_testyear')
plt.plot(np.log(np.median(nt_glm_test, axis=0)), color="C7", label='GLM_testyear')
plt.plot(np.log(np.median(nt_abc_test, axis=0)), color="C1", label='ABC_testyear')

plt.plot(np.log(nt_true[5:9]), color="r")

plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_random_test, 0.025, axis=0)), 
    np.log(np.quantile(nt_random_test, 0.975, axis=0)),
    color="C0",
    alpha=0.2,
)
plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_glm_test, 0.025, axis=0)), 
    np.log(np.quantile(nt_glm_test, 0.975, axis=0)),
    color="C7",
    alpha=0.2,
)
plt.fill_between(
    np.arange(4),
    np.log(np.quantile(nt_abc_test, 0.025, axis=0)), 
    np.log(np.quantile(nt_abc_test, 0.975, axis=0)),
    color="C1",
    alpha=0.2,
)
plt.xticks(ticks = np.arange(0, 4), labels= np.arange(2009, 2013), fontsize=14)
plt.legend(loc='lower left', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Log Population size', fontsize=12)
plt.ylim(3, 6.5)
plt.title('(D) GLM vs GP vs ABC', fontsize=12)

plt.suptitle('Long-term forecasting for testing years (2009-2012), given the true population at 2008', fontsize=16)
# plt.savefig('plot_2.pdf')  
plt.tight_layout()
plt.show()
